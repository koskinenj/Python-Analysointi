# %%
import pandas as pd 
import numpy as np

spotify = pd.read_csv('spotify_songs.csv')

# %% [markdown]
# Importoimme pandan, numpyn ja csv tiedoston python projektiin.

# %%
spotify = spotify.drop('track_id', axis=1)
spotify = spotify.drop('track_album_id', axis=1)
spotify = spotify.drop('playlist_id', axis=1)
spotify = spotify.drop('duration_ms', axis=1)
spotify = spotify.drop('loudness', axis=1)
spotify = spotify.drop('mode', axis=1)
spotify = spotify.drop('energy', axis=1)
spotify = spotify.drop('danceability', axis=1)
spotify = spotify.drop('key', axis=1)
spotify = spotify.drop('speechiness', axis=1)
spotify = spotify.drop('acousticness', axis=1)
spotify = spotify.drop('instrumentalness', axis=1)
spotify = spotify.drop('liveness', axis=1)
spotify = spotify.drop('valence', axis=1)
# Out:
#                                           track_name      track_artist  \
# 0  I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                    Memories - Dillon Francis Remix          Maroon 5
# 2                    All the Time - Don Diablo Remix      Zara Larsson
# 3                  Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4            Someone You Loved - Future Humans Remix     Lewis Capaldi
# 5  Beautiful People (feat. Khalid) - Jack Wins Remix        Ed Sheeran
# 6                    Never Really Over - R3HAB Remix        Katy Perry
# 7           Post Malone (feat. RANI) - GATTÜSO Remix         Sam Feldt
# 8             Tough Love - Tiësto Remix / Radio Edit            Avicii
# 9                If I Can't Have You - Gryffin Remix      Shawn Mendes
#
#    track_popularity                                   track_album_name  \
# 0                66  I Don't Care (with Justin Bieber) [Loud Luxury...
# ...

# %% [markdown]
# Poistimme ylimääräiset columnit, jotka olivat epäolennaisia kuluttajalle.
