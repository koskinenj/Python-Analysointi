# %%
# Import the necessary libraries
import pandas as pd
import numpy as np

spotify = pd.read_csv('spotify_songs.csv')

# %%
spotify.shape[0]
spotify.head(2000)
# Out:
#                   track_id                                         track_name  \
# 0   6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1   0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2   1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3   75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4   1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
# ..                     ...                                                ...
# 95  09IStsImFySgyp0pIQdqAc                                         The Middle
# 96  1lGVyEkGHUz7Pg78QGaS4a                                             Wanted
# 97  6ksMjdec8b6C45TUawkAdu                                      Crash Into Me
# 98  1vsQb8n0icvMsFnL9663LM                   Need Your Love (with Noah Kahan)
# 99  6pooRNiLyYpxZeIA5kJ5EX          Good Things Fall Apart (with Jon Bellion)
#
# ...

# %%
# to display the first 10 rows of the Pandas DataFrame called chipo
missing_count = spotify.isnull().sum()
print(missing_count)
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
spotify.fillna(0)
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...

# %%
spotify.shape
spotify.shape[0]
spotify.shape[1]
# Out:
# 23

# %%
spotify.index
# Out:
# RangeIndex(start=0, stop=32833, step=1)

# %%
# Get data types of multiple columns
column_data_types = spotify.dtypes
print(column_data_types)

# Get data type of a single column
# Out:
# track_id                     object
# track_name                   object
# track_artist                 object
# track_popularity              int64
# track_album_id               object
# track_album_name             object
# track_album_release_date     object
# playlist_name                object
# playlist_id                  object
# playlist_genre               object
# playlist_subgenre            object
# danceability                float64
# energy                      float64
# key                           int64
# loudness                    float64
# mode                          int64
# speechiness                 float64
# acousticness                float64
# instrumentalness            float64
# liveness                    float64
# valence                     float64
# tempo                       float64
# duration_ms                   int64
# dtype: object

# %%
chipo.sort_values("day", ascending=True)
# Out:
#            date  day  aircraft  helicopter  tank    APC  field artillery  MRL  \
# 0    2022-02-25    2        10           7    80    516               49    4
# 1    2022-02-26    3        27          26   146    706               49    4
# 2    2022-02-27    4        27          26   150    706               50    4
# 3    2022-02-28    5        29          29   150    816               74   21
# 4    2022-03-01    6        29          29   198    846               77   24
# ..          ...  ...       ...         ...   ...    ...              ...  ...
# 621  2023-11-08  623       322         324  5301   9996             7439  872
# 622  2023-11-09  624       322         324  5316  10014             7475  875
# 623  2023-11-10  625       322         324  5317  10017             7489  877
# 624  2023-11-11  626       322         324  5342  10041             7527  879
# 625  2023-11-12  627       322         324  5349  10073             7559  881
#
# ...

# %%
chipo['item_price'] = chipo['item_price'].str.replace('$','').astype(float)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'item_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Python Analysointi\pandatest.ipynb Cell 9 line 1
# ...

# %%
chipo['total'] = chipo['quantity']*chipo['item_price']

chipo.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total  \
# 0                                                NaN        2.39   2.39
# 1                                       [Clementine]        3.39   3.39
# 2                                            [Apple]        3.39   3.39
# 3                                                NaN        2.39   2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98  33.96
#
#   price_group
# 0       Halpa
# 1       Halpa
# 2       Halpa
# 3       Halpa
# 4      Kallis

# %%
def categorize_price(item_price):
    if item_price < 5:
        return 'Halpa'
    elif item_price < 10:
        return 'Keskihintainen'
    else:
        return 'Kallis'
    
chipo['price_group'] = chipo['item_price'].apply(categorize_price)

chipo.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total  \
# 0                                                NaN        2.39   2.39
# 1                                       [Clementine]        3.39   3.39
# 2                                            [Apple]        3.39   3.39
# 3                                                NaN        2.39   2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98  33.96
#
#   price_group
# 0       Halpa
# 1       Halpa
# 2       Halpa
# 3       Halpa
# 4      Kallis
